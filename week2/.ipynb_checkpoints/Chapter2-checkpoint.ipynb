# %% [markdown]
# # Notebook accompaning Chapter 2 from
#
#
# * Discovering knowledge in data : an introduction to data mining / Daniel T. Larose
#
# This notebook shows how we can do all things described in this chapter rather easily inside `pandas`.

# %% [markdown]
# ## Download all data
#
# * You can do this within Python of course, but from the shell it is super easy, using `wget`. The following command _recursively_ downloads all webpages "below" (that is the `-np` (for no parents)) the given url.
# * `wget -np -r http://www.sgi.com/tech/mlc/db/`
# * It will create a directory structure `www.sgi.com/tech/mlc/db/` below the working directory and put all files in there.

# %%
import pandas as pd
# %matplotlib inline
# !wget -np -r http://www.sgi.com/tech/mlc/db/
# Out:
# --2017-02-14 09:11:19--  http://www.sgi.com/tech/mlc/db/
# Resolving www.sgi.com... 192.48.178.134
# Connecting to www.sgi.com|192.48.178.134|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.sgi.com/tech/mlc/db/index.html’
#
# www.sgi.com/tech/ml     [  <=>               ]  27.56K  73.1KB/s    in 0.4s
#
# 2017-02-14 09:11:20 (73.1 KB/s) - ‘www.sgi.com/tech/mlc/db/index.html’ saved [28225]
#
# Loading robots.txt; please ignore errors.
# --2017-02-14 09:11:20--  http://www.sgi.com/robots.txt
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 196 [text/plain]
# Saving to: ‘www.sgi.com/robots.txt’
#
# www.sgi.com/robots. 100%[===================>]     196  --.-KB/s    in 0s
#
# 2017-02-14 09:11:20 (18.7 MB/s) - ‘www.sgi.com/robots.txt’ saved [196/196]
#
# --2017-02-14 09:11:20--  http://www.sgi.com/tech/mlc/db/adult.all
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6009997 (5.7M) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/adult.all’
#
# www.sgi.com/tech/ml 100%[===================>]   5.73M  1.64MB/s    in 3.5s
#
# 2017-02-14 09:11:23 (1.64 MB/s) - ‘www.sgi.com/tech/mlc/db/adult.all’ saved [6009997/6009997]
#
# --2017-02-14 09:11:23--  http://www.sgi.com/tech/mlc/db/adult.awk
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 453 [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/adult.awk’
#
# www.sgi.com/tech/ml 100%[===================>]     453  --.-KB/s    in 0s
#
# 2017-02-14 09:11:24 (43.2 MB/s) - ‘www.sgi.com/tech/mlc/db/adult.awk’ saved [453/453]
#
# --2017-02-14 09:11:24--  http://www.sgi.com/tech/mlc/db/adult.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 4006887 (3.8M) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/adult.data’
#
# www.sgi.com/tech/ml 100%[===================>]   3.82M  1.53MB/s    in 2.5s
#
# 2017-02-14 09:11:26 (1.53 MB/s) - ‘www.sgi.com/tech/mlc/db/adult.data’ saved [4006887/4006887]
#
# --2017-02-14 09:11:26--  http://www.sgi.com/tech/mlc/db/adult.doc
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 4357 (4.3K) [application/msword]
# Saving to: ‘www.sgi.com/tech/mlc/db/adult.doc’
#
# www.sgi.com/tech/ml 100%[===================>]   4.25K  --.-KB/s    in 0s
#
# 2017-02-14 09:11:26 (15.6 MB/s) - ‘www.sgi.com/tech/mlc/db/adult.doc’ saved [4357/4357]
#
# --2017-02-14 09:11:26--  http://www.sgi.com/tech/mlc/db/adult.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 5239 (5.1K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/adult.names’
#
# www.sgi.com/tech/ml 100%[===================>]   5.12K  --.-KB/s    in 0s
#
# 2017-02-14 09:11:27 (151 MB/s) - ‘www.sgi.com/tech/mlc/db/adult.names’ saved [5239/5239]
#
# --2017-02-14 09:11:27--  http://www.sgi.com/tech/mlc/db/adult.test
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length:
) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/australian.data’
#
# www.sgi.com/tech/ml 100%[===================>]  25.49K  --.-KB/s    in 0.003s
#
# 2017-02-14 09:11:33 (9.32 MB/s) - ‘www.sgi.com/tech/mlc/db/australian.data’ saved [26103/26103]
#
# --2017-02-14 09:11:33--  http://www.sgi.com/tech/mlc/db/australian.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 5015 (4.9K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/australian.names’
#
# www.sgi.com/tech/ml 100%[===================>]   4.90K  --.-KB/s    in 0.01s
#
# 2017-02-14 09:11:33 (499 KB/s) - ‘www.sgi.com/tech/mlc/db/australian.names’ saved [5015/5015]
#
# --2017-02-14 09:11:33--  http://www.sgi.com/tech/mlc/db/australian.test
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 12969 (13K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/australian.test’
#
# www.sgi.com/tech/ml 100%[===================>]  12.67K  --.-KB/s    in 0.003s
#
# 2017-02-14 09:11:33 (3.56 MB/s) - ‘www.sgi.com/tech/mlc/db/australian.test’ saved [12969/12969]
#
# --2017-02-14 09:11:33--  http://www.sgi.com/tech/mlc/db/auto.all
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 26141 (26K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/auto.all’
#
# www.sgi.com/tech/ml 100%[===================>]  25.53K  --.-KB/s    in 0.003s
#
# 2017-02-14 09:11:33 (8.71 MB/s) - ‘www.sgi.com/tech/mlc/db/auto.all’ saved [26141/26141]
#
# --2017-02-14 09:11:33--  http://www.sgi.com/tech/mlc/db/auto.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 19905 (19K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/auto.data’
#
# www.sgi.com/tech/ml 100%[===================>]  19.44K  --.-KB/s    in 0.002s
#
# 2017-02-14 09:11:34 (11.9 MB/s) - ‘www.sgi.com/tech/mlc/db/auto.data’ saved [19905/19905]
#
# --2017-02-14 09:11:34--  http://www.sgi.com/tech/mlc/db/auto.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6310 (6.2K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/auto.names’
#
# www.sgi.com/tech/ml 100%[===================>]   6.16K  --.-KB/s    in 0s
#
# 2017-02-14 09:11:34 (182 MB/s) - ‘www.sgi.com/tech/mlc/db/auto.names’ saved [6310/6310]
#
# --2017-02-14 09:11:34--  http://www.sgi.com/tech/mlc/db/auto.test
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 10053 (9.8K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/auto.test’
#
# www.sgi.com/tech/ml 100%[===================>]   9.82K  --.-KB/s    in 0s
#
# 2017-02-14 09:11:34 (34.6 MB/s) - ‘www.sgi.com/tech/mlc/db/auto.test’ saved [10053/10053]
#
# --2017-02-14 09:11:34--  http://www.sgi.com/tech/mlc/db/balance-scale.all
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6250 (6.1K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/balance-scale.all’
#
# www.sgi.com/tech/ml 100%[===================>]   6.10K  --.-KB/s    in 0s
#
# 2017-02-14 09:11:34 (82.8 MB/s) - ‘www.sgi.com/tech/mlc/db/balance-scale.all’ saved [6250/6250]
#
# --2017-02-14 09:11:34--  http://www.sgi.com/tech/mlc/db/balance-scale.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6262 (6.1K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/balance-scale.data’
#
# www.sgi.com/tech/ml 100%[===================>]   6.12K  --.-KB/s    in 0s
#
# 2017-02-14 09:11:34 (314 MB/s) - ‘www.sgi.com/tech/mlc/db/balance-scale.data’ saved [6262/6262]
#
# --2017-02-14 09:11:34--  http://www.sgi.com/tech/mlc/db/balance-scale.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 2609 (2.5K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db
) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/cleveland-nominal.data’
#
# www.sgi.com/tech/ml 100%[===================>]   4.73K  --.-KB/s    in 0.004s
#
# 2017-02-14 09:11:43 (1.22 MB/s) - ‘www.sgi.com/tech/mlc/db/cleveland-nominal.data’ saved [4848/4848]
#
# --2017-02-14 09:11:43--  http://www.sgi.com/tech/mlc/db/cleveland-nominal.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 481 [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/cleveland-nominal.names’
#
# www.sgi.com/tech/ml 100%[===================>]     481  --.-KB/s    in 0.001s
#
# 2017-02-14 09:11:43 (351 KB/s) - ‘www.sgi.com/tech/mlc/db/cleveland-nominal.names’ saved [481/481]
#
# --2017-02-14 09:11:43--  http://www.sgi.com/tech/mlc/db/cleve.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 1390 (1.4K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/cleve.names’
#
# www.sgi.com/tech/ml 100%[===================>]   1.36K  --.-KB/s    in 0.001s
#
# 2017-02-14 09:11:43 (948 KB/s) - ‘www.sgi.com/tech/mlc/db/cleve.names’ saved [1390/1390]
#
# --2017-02-14 09:11:43--  http://www.sgi.com/tech/mlc/db/cleve.test
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 7338 (7.2K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/cleve.test’
#
# www.sgi.com/tech/ml 100%[===================>]   7.17K  --.-KB/s    in 0.02s
#
# 2017-02-14 09:11:44 (407 KB/s) - ‘www.sgi.com/tech/mlc/db/cleve.test’ saved [7338/7338]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/corral.all
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 2708 (2.6K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/corral.all’
#
# www.sgi.com/tech/ml 100%[===================>]   2.64K  --.-KB/s    in 0.002s
#
# 2017-02-14 09:11:44 (1.51 MB/s) - ‘www.sgi.com/tech/mlc/db/corral.all’ saved [2708/2708]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/corral.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 482 [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/corral.data’
#
# www.sgi.com/tech/ml 100%[===================>]     482  --.-KB/s    in 0.001s
#
# 2017-02-14 09:11:44 (535 KB/s) - ‘www.sgi.com/tech/mlc/db/corral.data’ saved [482/482]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/corral.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 1881 (1.8K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/corral.names’
#
# www.sgi.com/tech/ml 100%[===================>]   1.84K  --.-KB/s    in 0.006s
#
# 2017-02-14 09:11:44 (286 KB/s) - ‘www.sgi.com/tech/mlc/db/corral.names’ saved [1881/1881]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/corral.test
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 2708 (2.6K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/corral.test’
#
# www.sgi.com/tech/ml 100%[===================>]   2.64K  --.-KB/s    in 0.002s
#
# 2017-02-14 09:11:44 (1.23 MB/s) - ‘www.sgi.com/tech/mlc/db/corral.test’ saved [2708/2708]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/crx.all
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 33215 (32K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/crx.all’
#
# www.sgi.com/tech/ml 100%[===================>]  32.44K  --.-KB/s    in 0.03s
#
# 2017-02-14 09:11:44 (1.08 MB/s) - ‘www.sgi.com/tech/mlc/db/crx.all’ saved [33215/33215]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/crx.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 23561 (23K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/crx.data’
#
# www.sgi.com/tech/ml 100%[===================>]  23.01K  --.-KB/s    in 0.002s
#
# 2017-02-14 09:11:44 (12.2 MB/s) - ‘www.sgi.com/tech/mlc/db/crx.data’ saved [23561/23561]
#
# --2017-02-14 09:11:44--  http://www.sgi.com/tech/mlc/db/crx.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length:
) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/horse-colic.all’
#
# www.sgi.com/tech/ml 100%[===================>]  20.79K  --.-KB/s    in 0.002s
#
# 2017-02-14 09:11:56 (12.2 MB/s) - ‘www.sgi.com/tech/mlc/db/horse-colic.all’ saved [21292/21292]
#
# --2017-02-14 09:11:56--  http://www.sgi.com/tech/mlc/db/horse-colic.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 17316 (17K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/horse-colic.data’
#
# www.sgi.com/tech/ml 100%[===================>]  16.91K  --.-KB/s    in 0.05s
#
# 2017-02-14 09:11:56 (318 KB/s) - ‘www.sgi.com/tech/mlc/db/horse-colic.data’ saved [17316/17316]
#
# --2017-02-14 09:11:56--  http://www.sgi.com/tech/mlc/db/horse-colic.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 10469 (10K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/horse-colic.names’
#
# www.sgi.com/tech/ml 100%[===================>]  10.22K  --.-KB/s    in 0.02s
#
# 2017-02-14 09:11:56 (447 KB/s) - ‘www.sgi.com/tech/mlc/db/horse-colic.names’ saved [10469/10469]
#
# --2017-02-14 09:11:56--  http://www.sgi.com/tech/mlc/db/horse-colic.test
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 3976 (3.9K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/horse-colic.test’
#
# www.sgi.com/tech/ml 100%[===================>]   3.88K  --.-KB/s    in 0.005s
#
# 2017-02-14 09:11:57 (841 KB/s) - ‘www.sgi.com/tech/mlc/db/horse-colic.test’ saved [3976/3976]
#
# --2017-02-14 09:11:57--  http://www.sgi.com/tech/mlc/db/hungarian.all
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 10263 (10K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/hungarian.all’
#
# www.sgi.com/tech/ml 100%[===================>]  10.02K  --.-KB/s    in 0.001s
#
# 2017-02-14 09:11:57 (8.27 MB/s) - ‘www.sgi.com/tech/mlc/db/hungarian.all’ saved [10263/10263]
#
# --2017-02-14 09:11:57--  http://www.sgi.com/tech/mlc/db/hungarian.data
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 9605 (9.4K) [text/plain]
# Saving to: ‘www.sgi.com/tech/mlc/db/hungarian.data’
#
# www.sgi.com/tech/ml 100%[===================>]   9.38K  --.-KB/s    in 0.002s
#
# 2017-02-14 09:11:57 (5.04 MB/s) - ‘www.sgi.com/tech/mlc/db/hungarian.data’ saved [9605/9605]
#
# --2017-02-14 09:11:57--  http://www.sgi.com/tech/mlc/db/hungarian.names
# Reusing existing connection to www.sgi.com:80.
# HTTP request sent, awaiting response...

# %%
# list all the datasets in the  www.sgi.com/tech/mlc/db folder
ls www.sgi.com/tech/mlc/db/*.data
# Out:
# Warning: wildcards not supported in HTTP.
# --2017-02-14 09:10:31--  http://www.sgi.com/tech/mlc/db/*.data
# Resolving www.sgi.com... 192.48.178.134
# Connecting to www.sgi.com|192.48.178.134|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2017-02-14 09:10:32 ERROR 404: Not Found.

# %%
ls -lh www.sgi.com/tech/mlc/db/cars*
# Out:
# -rw-r--r--  1 admin  staff    17K Feb 27  2001 www.sgi.com/tech/mlc/db/cars.all
# -rw-r--r--  1 admin  staff    12K Feb 27  2001 www.sgi.com/tech/mlc/db/cars.data
# -rw-r--r--  1 admin  staff   362B Feb 27  2001 www.sgi.com/tech/mlc/db/cars.names
# -rw-r--r--  1 admin  staff   5.9K Feb 27  2001 www.sgi.com/tech/mlc/db/cars.test
# -rw-r--r--  1 admin  staff    15K Feb 27  2001 www.sgi.com/tech/mlc/db/cars1.all
# -rw-r--r--  1 admin  staff   9.8K Feb 27  2001 www.sgi.com/tech/mlc/db/cars1.data
# -rw-r--r--  1 admin  staff   366B Feb 27  2001 www.sgi.com/tech/mlc/db/cars1.names
# -rw-r--r--  1 admin  staff   4.9K Feb 27  2001 www.sgi.com/tech/mlc/db/cars1.test

# %% [markdown]
# # Let's try
#
# * Let us just try to read in the data with pandas

# %%
carsdf= pd.read_csv('www.sgi.com/tech/mlc/db/cars.data')
print carsdf.shape
carsdf.head()
# Out:
# (261, 1)
#                                        |1x3 Cross validator
# 14.0 8 350 165 4209 12 1972  chevrolet                  US.
# 31.9 4 89  71  1925 14 1980  vw                     Europe.
# 17.0 8 302 140 3449 11 1971  ford                       US.
# 15.0 8 400 150 3761 10 1971  chevrolet                  US.
# 30.5 4 98  63  2051 17 1978  chevrolet                  US.

# %% [markdown]
# * That does not look good.
# * Let's check out the file. In linux we can do that using `head` or `cat`: these commands just print the file to the terminal.
#
# ### What do we learn?
# * first line should go
# * the file does not have column headers
# * comma separated (that is good, that is the default in pandas).
#
# ### How to fix this?
# * Learn the arguments of `pd.read_csv` by running `pd.read_csv?`
# * Only use Google if the manual that you can access does not give you the information

# %%
# !head www.sgi.com/tech/mlc/db/cars.data
# Out:
# |1x3 Cross validator
# 14, 8, 350, 165, 4209, 12, 1972, chevrolet, US.
# 31.9, 4, 89, 71, 1925, 14, 1980, vw, Europe.
# 17, 8, 302, 140, 3449, 11, 1971, ford, US.
# 15, 8, 400, 150, 3761, 10, 1971, chevrolet, US.
# 30.5, 4, 98, 63, 2051, 17, 1978, chevrolet, US.
# 23, 8, 350, 125, 3900, 17, 1980, cadillac, US.
# 13, 8, 351, 158, 4363, 13, 1974, ford, US.
# 14, 8, 440, 215, 4312, 9, 1971, plymouth, US.
# 25.4, 5, 183, 77, 3530, 20, 1980, mercedes, Europe.

# %%
carsdf= pd.read_csv('www.sgi.com/tech/mlc/db/cars.data', skiprows=1, 
                    names=['mpg','cylinders','cubicinches','hp','no_idea','no_idea2','year','brand','country'])
carsdf.head()
# Out:
#     mpg  cylinders  cubicinches   hp  no_idea  no_idea2  year       brand  \
# 0  14.0          8          350  165     4209        12  1972   chevrolet
# 1  31.9          4           89   71     1925        14  1980          vw
# 2  17.0          8          302  140     3449        11  1971        ford
# 3  15.0          8          400  150     3761        10  1971   chevrolet
# 4  30.5          4           98   63     2051        17  1978   chevrolet
#
#     country
# 0       US.
# 1   Europe.
# 2       US.
# 3       US.
# 4       US.

# %%
carsdf.describe()
# Out:
#               mpg   cylinders  cubicinches          hp      no_idea  \
# count  261.000000  261.000000   261.000000  261.000000   261.000000
# mean    23.144828    5.590038   201.103448  106.360153  3005.490421
# std      7.823570    1.733310   108.879683   40.499959   852.645596
# min     10.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     16.900000    4.000000   101.000000   75.000000  2246.000000
# 50%     22.000000    6.000000   156.000000   95.000000  2835.000000
# 75%     28.800000    8.000000   302.000000  138.000000  3664.000000
# max     46.600000    8.000000   455.000000  230.000000  4997.000000
#
#          no_idea2         year
# count  261.000000   261.000000
# mean    15.547893  1976.819923
# std      2.910625     3.637696
# min      8.000000  1971.000000
# 25%     14.000000  1974.000000
# 50%     16.000000  1977.000000
# 75%     17.000000  1980.000000
# max     25.000000  1983.000000

# %% [markdown]
# # Missing values
#
# In the book they perform the following techniques on missing values:
#
# 1. Replace the missing value with some constant, specified by the analyst.
# 2. Replace the missing value with the field mean (for numerical variables) or the mode (for categorical variables).
# 3. Replace the missing values with a value generated at random from the variable distribution observed.
#
# ### How to do that in pandas?
#
# * See <http://pandas.pydata.org/pandas-docs/stable/missing_data.html>
#
# * [How do missing values look like?](http://pandas.pydata.org/pandas-docs/stable/missing_data.html#values-considered-missing) Easy, like `NaN` or `None`.
# * How to check for missing values?
#     * **Your turn** Figure out what `carsdf.isnull()` and `.notnull()` are doing. You can ask pandas of course using `carsdf.isnull?`. Now what is `carsdf.year.notnull()`, and what does it say? And what about `carsdf.isnull().mean()` and `carsdf.notnull().mean()`? What do they say?
#     * **Your turn 2** Create out of our cars file a file _with the same missing data as in the book_, and then experiment with the same commands.
# * [Cleaning and filling missing data](http://pandas.pydata.org/pandas-docs/stable/missing_data.html#cleaning-filling-missing-data)
#     * **Your turn** Find out how to replace missing values with a constant
#         * everywhere with the same constant
#         * just for one or a few specified columns
#     * **Your turn** Find out how to replace missing values with the columns mean
#         * everywhere
#         * just for one or a few specified columns
#     * **Your turn** Find out how to replace missing values with a random value from the column
#         * all missing values in a column with the same random value is easy.
#         * can you do it when picking a new random value for every missing value?
#         *  Try the `random` module and consider a command like `carsdf.year.values`
#
#
# ### Pandas can do much more
#
# Continue reading  <http://pandas.pydata.org/pandas-docs/stable/missing_data.html> and you learn great things about missing value handling in Pandas. Also the value normalization using regular expressions and `replace` is very useful.

# %%
carsdf.country.str.replace('.','').head()
# Out:
# 0         US
# 1     Europe
# 2         US
# 3         US
# 4         US
# Name: country, dtype: object

# %%
carsdf.country.str.replace(r'U.*','USA').head()
# Out:
# 0         USA
# 1     Europe.
# 2         USA
# 3         USA
# 4         USA
# Name: country, dtype: object

# %% [markdown]
# # IDENTIFYING MISCLASSIFICATIONS
#
# ### Get a histogram of the values in a column

# %%
# Get a histogram of the values in a column

carsdf.country.value_counts()
# Out:
#  US.        162
#  Japan.      51
#  Europe.     48
# Name: country, dtype: int64

# %%
carsdf.country.value_counts().plot(kind='barh');

# %%
carsdf.country.value_counts().plot

# %%
carsdf.year.value_counts()
# Out:
# 1974    35
# 1977    26
# 1971    23
# 1976    22
# 1980    21
# 1979    21
# 1982    18
# 1981    18
# 1978    18
# 1983    16
# 1973    16
# 1972    15
# 1975    12
# Name: year, dtype: int64

# %%
carsdf.year.value_counts().plot(kind ='bar');

# %%
carsdf.year.value_counts().sort_index().plot(kind ='bar');
print carsdf.year.describe()
# Out:
# count     261.000000
# mean     1976.819923
# std         3.637696
# min      1971.000000
# 25%      1974.000000
# 50%      1977.000000
# 75%      1980.000000
# max      1983.000000
# Name: year, dtype: float64

# %% [markdown]
# # Your turn
#
# * Reproduce figure 2.5

# %% [markdown]
# # Scatter plots
#
# * **Your turn**: try to reproduce Figure 2.6.
# * I could not find those outliers in the given datasets....
# * Experiment with the extra parameters that you can give. Try to add those arrows as well.

# %%
carsdf.plot.scatter(x='no_idea',y='mpg', title='Scatterplot');

# %%
# Simply adding a regression line

import seaborn as sns
sns.lmplot(x='no_idea',y='mpg',data=carsdf,fit_reg=True);

# %%
carsdf2= pd.read_csv('www.sgi.com/tech/mlc/db/cars.all',   
                    names=['mpg','cylinders','cubicinches','hp','no_idea','no_idea2','year','brand','country'])
sns.lmplot(x='no_idea',y='mpg',data=carsdf2,fit_reg=True);

# %% [markdown]
# # DATA TRANSFORMATION
#
# ### Your turn
# * Reproduce Figure 2.7

# %% [markdown]
# ## Min–Max Normalization
#
# * Here we show how easy you program min-max normalization in pandas.
#
# * **Your turn**: do the same but now for **time-to-60**

# %%
df= carsdf2.mpg

dfnorm=(df - df.min()) / (df.max() - df.min())

print dfnorm.describe()

dfnorm.plot();
# Out:
# count    392.000000
# mean       0.384200
# std        0.207580
# min        0.000000
# 25%        0.212766
# 50%        0.365691
# 75%        0.531915
# max        1.000000
# Name: mpg, dtype: float64

# %% [markdown]
# ## Z-Score Standardization
#
# * **Your turn**
#     * Compute the Z score normalization for _time to 60_
#     * reproduce Figure 2.8
# * **Hint** Use df. TAB to see which methods exist for a series or a dataframe. Maybe the method for the mean of a column is called ....

# %% [markdown]
# # Your turn
#
# Make all exercises from Chapter 2.
#
#
#
# 1. Describethepossiblenegativeeffectsofproceedingdirectlytominedatathathasnotbeen preprocessed.
# 2. Find the mean value for the income attribute of the five customers in Table 2.1 before preprocessing. What does this number actually mean? Calculate the mean income for the three values left after preprocessing. Does this value have a meaning?
# 3. Which of the three methods from Figures 2.2 to 2.4 do you prefer for handling missing
# values?
# a. Which method is the most conservative and probably the safest, meaning that it fabri- cates the least amount of data? What are some drawbacks to this method?
# b. Which method would tend to lead to an underestimate of the spread (e.g., standard deviation) of the variable? What are some benefits to this method?
# c. What are some benefits and drawbacks of the method that chooses values at random from the variable distribution?
# 4. Make up a classification scheme that is inherently flawed and would lead to misclassifi- cation, as we find in Table 2.2: for example, classes of items bought in a grocery store.
# 5. Make up a data set consisting of eight scores on an exam in which one of the scores is an outlier.
# a. Find the mean score and the median score, with and without the outlier.
# b. State which measure, the mean or the median, the presence of the outlier affects more,
# and why. (Mean, median, and other statistics are explained in Chapter 4.)
# c. Verify that the outlier is indeed an outlier, using the IQR method.
# 6. Make up a data set, consisting of the heights and weights of six children, in which one of the children, but not the other, is an outlier with respect to one of the variables. Then alter this data set so that the child is an outlier with respect to both variables.
# 7. UsingyourdatasetfromExercise5,findthemin–maxnormalizationofthescores.Verify that each value lies between zero and
#
# ## Hands-on Analysis
# Use the churn data set at the book series Web site for the following exercises.
#
# 8. Explore whether there are missing values for any of the variables.
# 9. Compare the area code and state fields. Discuss any apparent abnormalities.
# 10. Use a graph to determine visually whether there are any outliers among the number of calls to customer service.
# 11. Transform the day minutes attribute using min–max normalization. Verify using a graph that all values lie between zero and 1.
# 12. Transform the night minutes attribute using Z-score standardization. Using a graph, de- scribe the range of the standardized values.
